# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
import random
from imblearn.over_sampling import SMOTE
file_path = "creditcard.csv"
df = pd.read_csv(file_path)

# %%
df.head()
print(df.dtypes)
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
# Split the data into features (X) and target variable (y)
X = df.drop("Class", axis = 1)
y = df["Class"]
# Split the data into training and testing sets 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0) # seed in random generation

# %%
# Train the logistic regression model
logistic_regression = LogisticRegression()

logistic_regression.fit(X_train, y_train)
# Out:
# C:\Users\JEWEL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Predicting 
y_pred = logistic_regression.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(56962,))

# %%
y_test
# Out:
# 183484    0
# 255448    0
# 244749    0
# 63919     0
# 11475     0
#          ..
# 236778    0
# 127073    0
# 208502    0
# 263323    0
# 246221    0
# Name: Class, Length: 56962, dtype: int64

# %%
f1_lr = f1_score(y_test, y_pred, average='binary')
print(f1_lr)
# Out:
# 0.7010309278350515

# %%
accuracy_mlp = accuracy_score(y_test, y_pred, normalize=True)
print(accuracy_mlp)
# Out:
# 0.9989817773252344

# %%
roc_mlp = roc_auc_score(y_test, y_pred, average='macro')
print(roc_mlp)
# Out:
# 0.8364138290334899

# %%
df['Class'].count()
# Out:
# np.int64(284807)

# %%
class_counts = df['Class'].value_counts()
print(class_counts)
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# Get the minimum class count
min_count = class_counts.min()
print(min_count)
# Out:
# 492

# %%
a= 0
b = df['Class'].index

# %%
# Randomly sample the dataset to balance it (undersampling)
balanced_df = df.groupby('Class').apply(lambda x: x.sample(min_count)).reset_index(drop=True)

# Checking the size of each class after applying undersampling
class_sizes = balanced_df['Class'].value_counts()
print(class_sizes)
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64
# C:\Users\JEWEL\AppData\Local\Temp\ipykernel_19940\3746506738.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   balanced_df = df.groupby('Class').apply(lambda x: x.sample(min_count)).reset_index(drop=True)

# %%
balanced_df[balanced_df['Class']==1]['Class'].count()/balanced_df['Class'].count()

# %%
balanced_df[balanced_df['Class']==0]['Class'].count()/balanced_df['Class'].count()
# Out:
# np.float64(0.5)

# %%
# Split the data into features (X) and target variable (y)
X = balanced_df.drop("Class", axis = 1)
y = balanced_df["Class"]
# Splot the data into training and testing sets 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0) # seed in random generation

# %%
# Train the logistic regression model
logistic_regression = LogisticRegression()

logistic_regression.fit(X_train, y_train)
# Out:
# C:\Users\JEWEL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Predicting 
y_pred = logistic_regression.predict(X_test)

# %%
f1_lr = f1_score(y_test, y_pred, average='binary')
print(f1_lr)
# Out:
# 0.7010309278350515

# %%
accuracy_mlp = accuracy_score(y_test, y_pred, normalize=True)
print(accuracy_mlp)
# Out:
# 0.9989817773252344

# %%
roc_mlp = roc_auc_score(y_test, y_pred, average='macro')
print(roc_mlp)
# Out:
# 0.8364138290334899

# %%
# Random oversampling
# Count the number of observations in each class
class_counts = df['Class'].value_counts()
print(class_counts)

# Get the maximum class count (majority class count)
max_count = class_counts.max()
print(max_count)

# Perform oversampling
oversampled_df = (df.groupby('Class')
                  .apply(lambda x: x.sample(max_count, replace=True))
                  .reset_index(drop=True))

# Checking the size of each class after applying oversampling
class_sizes = oversampled_df['Class'].value_counts()
print(class_sizes)
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64
# 284315
# Class
# 0    284315
# 1    284315
# Name: count, dtype: int64
# C:\Users\JEWEL\AppData\Local\Temp\ipykernel_19940\4116248237.py:12: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sample(max_count, replace=True))

# %%
# Split the data into features (X) and target variable (y)
X = df.drop("Class", axis = 1)
y = df["Class"]

# Apply SMOTE to balance the dataset
smote = SMOTE()
X, y = smote.fit_resample(X, y)

# Splot the data into training and testing sets 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0) # seed in random generation

# %%
# Train the logistic regression model
logistic_regression = LogisticRegression()

logistic_regression.fit(X_train, y_train)
# Out:
# C:\Users\JEWEL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# Predicting 
y_pred = logistic_regression.predict(X_test)

f1_lr = f1_score(y_test, y_pred, average='binary')
print(f1_lr)

accuracy_mlp = accuracy_score(y_test, y_pred, normalize=True)
print(accuracy_mlp)

roc_mlp = roc_auc_score(y_test, y_pred, average='macro')
print(roc_mlp)
# Out:
# 0.8290204370720892
# 0.853533932434096
# 0.8538895009457603

# %%
# Split the data into features (X) and target variable (y)
X = df.drop("Class", axis = 1)
y = df["Class"]


# Splot the data into training and testing sets 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0) # seed in random generation

# %%
# Predicting 
y_pred = logistic_regression.predict(X_test)

f1_lr = f1_score(y_test, y_pred, average='binary')
print(f1_lr)

accuracy_mlp = accuracy_score(y_test, y_pred, normalize=True)
print(accuracy_mlp)

roc_mlp = roc_auc_score(y_test, y_pred, average='macro')
print(roc_mlp)
# Out:
# 0.7010309278350515
# 0.9989817773252344
# 0.8364138290334899
